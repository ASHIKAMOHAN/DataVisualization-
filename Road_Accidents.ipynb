# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([2,6])
ypoints=np.array([4,8])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as np
import numpy as np
xpoints=np.array([2,3,4,5])
ypoints=np.array([1,6,7,8])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([2,3])
ypoints=np.array([6,7])
plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([2,3])
ypoints=np.array([6,7])
plt.plot(xpoints,ypoints,'*k')
plt.show()

# %%
import matplotlib.pyplot as plt
xpoints=([2,3,4,5,6,7])
ypoints=([1,3,4,5,6,9])
plt.plot(xpoints,ypoints)
plt.label("xaxis")
plt.label("yaxis")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       3 ypoints=([1,3,4,5,6,9])
#       4 plt.plot(xpoints,ypoints)
# ----> 5 plt.label("xaxis")
#       6 plt.label("yaxis")
#       7 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'label'

# %%
from matplotlib import pyplot as plt
import numpy as np
fig = plt.figure()
data=np.array([1,2,3,4])
plt.plot(data)
fig.suptitle('GRAPH')
plt.xlabel('xlabel')
plt.ylabel('ylabel')
# Out:
# Text(0, 0.5, 'ylabel')

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)


plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import numpy as np
x=np.arange(5)
y=x**3
plt.plot([1,2,3,4],"ro",x,y,"k*")
plt.show()

# %%
xpoints=([2,3,4,5])
ypoints=([6,7,8,9])
plt.bar(xpoints,ypoints)
plt.show()

# %%
ypoints=([6,7,9,16])
plt.hist(ypoints)
plt.show()

# %%
xpoints=([1,2,3,4])
ypoints=([6,7,8,9])
plt.scatter(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([1,2,3,4])
ypoints=np.array([5,6,7,8])
plt.subplot(2,3,1)
plt.plot(xpoints,ypoints)


xpoints=np.array([1,2,3,4])
ypoints=np.array([2,3,4,5])
plt.subplot(2,3,2)
plt.plot(xpoints,ypoints)

xpoints=np.array([1,2,3,4])
ypoints=np.array([3,5,6,7])
plt.subplot(2,3,3)
plt.plot(xpoints,ypoints)

xpoints=np.array([11,12,13,14])
ypoints=np.array([15,16,17,18])
plt.subplot(2,3,4)
plt.plot(xpoints,ypoints)

xpoints=np.array([13,23,33,43])
ypoints=np.array([35,36,37,38])
plt.subplot(2,3,5)
plt.plot(xpoints,ypoints)

xpoints=np.array([9,12,13,14])
ypoints=np.array([15,16,17,18])
plt.subplot(2,3,6)
plt.plot(xpoints,ypoints)

plt.show()

# %%
xpoints=np.array([1,2,3,4])
ypoints=np.array([5,6,7,8])
plt.subplot(2,4,1)
plt.plot(xpoints,ypoints)

xpoints=np.array([1,2,3,4])
ypoints=np.array([2,3,4,5])
plt.subplot(2,4,2)
plt.plot(xpoints,ypoints)

xpoints=np.array([1,2,3,4])
ypoints=np.array([3,5,6,7])
plt.subplot(2,4,3)
plt.plot(xpoints,ypoints)

xpoints=np.array([11,12,13,14])
ypoints=np.array([15,16,17,18])
plt.subplot(2,4,4)
plt.plot(xpoints,ypoints)

xpoints=np.array([13,23,33,43])
ypoints=np.array([35,36,37,38])
plt.subplot(2,4,5)
plt.plot(xpoints,ypoints)

xpoints=np.array([9,12,13,14])
ypoints=np.array([15,16,17,18])
plt.subplot(2,4,6)
plt.plot(xpoints,ypoints)

xpoints=np.array([9,22,33,94])
ypoints=np.array([15,16,17,18])
plt.subplot(2,4,7)
plt.plot(xpoints,ypoints)

xpoints=np.array([3,4,5,6])
ypoints=np.array([15,16,17,18])
plt.subplot(2,4,8)
plt.plot(xpoints,ypoints)

plt.show()

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\ashik\\Downloads\\archive\\India_Injury_Road_Accident_Fatality_2017-2020.csv")
df
# Out:
#                           State  Road Accidents  during 2018  \
# 0                Andhra Pradesh                        24475
# 1             Arunachal Pradesh                          277
# 2                         Assam                         8248
# 3                         Bihar                         9600
# 4                  Chhattisgarh                        13864
# 5                           Goa                         3709
# 6                       Gujarat                        18769
# 7                       Haryana                        11238
# 8              Himachal Pradesh                         3110
# 9             Jammu and Kashmir                         5978
# 10                    Jharkhand                         5394
# 11                    Karnataka                        41707
# 12                       Kerala                        40181
# 13               Madhya Pradesh                        51397
# ...

# %%
df.head(10)
# Out:
#                State  Road Accidents  during 2018  \
# 0     Andhra Pradesh                        24475
# 1  Arunachal Pradesh                          277
# 2              Assam                         8248
# 3              Bihar                         9600
# 4       Chhattisgarh                        13864
# 5                Goa                         3709
# 6            Gujarat                        18769
# 7            Haryana                        11238
# 8   Himachal Pradesh                         3110
# 9  Jammu and Kashmir                         5978
#
#     Road Accidents  during 2019  Road Accidents  during 2020  \
# 0                         21992                      19509.0
# 1                           237                        134.0
# 2                          8350                       6595.0
# 3                         10007                       8639.0
# 4                         13899                      11656.0
# ...

# %%
df.tail(10)
# Out:
#                           State  Road Accidents  during 2018  \
# 27                Uttar Pradesh                        42568
# 28                  West Bengal                        12705
# 29  Andaman and Nicobar Islands                          254
# 30                   Chandigarh                          316
# 31       Dadra and Nagar Haveli                           80
# 32                Daman and Diu                           76
# 33                        Delhi                         6515
# 34                  Lakshadweep                            3
# 35                   Puducherry                         1597
# 36                       Total                        467044
#
#      Road Accidents  during 2019  Road Accidents  during 2020  \
# 27                         42572                      34243.0
# 28                         10158                       9180.0
# 29                           230                        141.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 45 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   State                                                  37 non-null     object
#  1   Road Accidents  during 2018                            37 non-null     int64
#  2    Road Accidents  during 2019                           37 non-null     int64
#  3   Road Accidents  during 2020                            36 non-null     float64
#  4   Accidents  Per Lakh Population - 2017                  36 non-null     float64
#  5   Total Number of Accidents  Per Lakh Population - 2018  36 non-null     float64
#  6   Total Number of Accidents  Per Lakh Population - 2019  36 non-null     float64
#  7   Total Number of Accidents  Per Lakh Population - 2020  36 non-null     float64
# ...

# %%
df.describe()
# Out:
#        Road Accidents  during 2018   Road Accidents  during 2019  \
# count                    37.000000                     37.000000
# mean                  25245.621622                  24270.378378
# std                   76481.808322                  73512.475713
# min                       3.000000                      1.000000
# 25%                     430.000000                    482.000000
# 50%                    6428.000000                   5796.000000
# 75%                   21743.000000                  21570.000000
# max                  467044.000000                 449002.000000
#
#        Road Accidents  during 2020  Accidents  Per Lakh Population - 2017  \
# count                    36.000000                              36.000000
# mean                  20341.000000                              37.144444
# std                   60695.640816                              35.992852
# min                       1.000000                               1.200000
# ...

# %%
df.max()
# Out:
# State                                                    West Bengal
# Road Accidents  during 2018                                   467044
#  Road Accidents  during 2019                                  449002
# Road Accidents  during 2020                                 366138.0
# Accidents  Per Lakh Population - 2017                          189.4
# Total Number of Accidents  Per Lakh Population - 2018          175.2
# Total Number of Accidents  Per Lakh Population - 2019          158.5
# Total Number of Accidents  Per Lakh Population - 2020          109.4
# Accidents per 10,000 Vehicles - 2017                            40.5
# Accidents per 10,000 Vehicles - 2018                            38.9
# Accidents per 10,000 Vehicles - 2019                            38.4
# Accidents per 10,000 Km of Roads - 2017                       5221.8
# Accidents per 10,000 Km of Roads - 2018                       3720.1
# Persons Killed 2017                                           147913
# ...

# %%
df.min()
# Out:
# State                                                    Andaman and Nicobar Islands
# Road Accidents  during 2018                                                        3
#  Road Accidents  during 2019                                                       1
# Road Accidents  during 2020                                                      1.0
# Accidents  Per Lakh Population - 2017                                            1.2
# Total Number of Accidents  Per Lakh Population - 2018                            3.6
# Total Number of Accidents  Per Lakh Population - 2019                            1.2
# Total Number of Accidents  Per Lakh Population - 2020                            0.0
# Accidents per 10,000 Vehicles - 2017                                             0.6
# Accidents per 10,000 Vehicles - 2018                                             1.7
# Accidents per 10,000 Vehicles - 2019                                             0.6
# ...

# %%
df.isnull().sum()
# Out:
# State                                                    0
# Road Accidents  during 2018                              0
#  Road Accidents  during 2019                             0
# Road Accidents  during 2020                              1
# Accidents  Per Lakh Population - 2017                    1
# Total Number of Accidents  Per Lakh Population - 2018    1
# Total Number of Accidents  Per Lakh Population - 2019    1
# Total Number of Accidents  Per Lakh Population - 2020    1
# Accidents per 10,000 Vehicles - 2017                     0
# Accidents per 10,000 Vehicles - 2018                     1
# Accidents per 10,000 Vehicles - 2019                     1
# Accidents per 10,000 Km of Roads - 2017                  0
# Accidents per 10,000 Km of Roads - 2018                  0
# Persons Killed 2017                                      0
# Persons Killed 2018                                      0
# Persons Killed 2019                                      0
# ...

# %%
df.isnull().any()
# Out:
# State                                                    False
# Road Accidents  during 2018                              False
#  Road Accidents  during 2019                             False
# Road Accidents  during 2020                               True
# Accidents  Per Lakh Population - 2017                     True
# Total Number of Accidents  Per Lakh Population - 2018     True
# Total Number of Accidents  Per Lakh Population - 2019     True
# Total Number of Accidents  Per Lakh Population - 2020     True
# Accidents per 10,000 Vehicles - 2017                     False
# Accidents per 10,000 Vehicles - 2018                      True
# Accidents per 10,000 Vehicles - 2019                      True
# Accidents per 10,000 Km of Roads - 2017                  False
# Accidents per 10,000 Km of Roads - 2018                  False
# Persons Killed 2017                                      False
# Persons Killed 2018                                      False
# ...

# %%
df.shape
# Out:
# (37, 45)

# %%
df.memory_usage()
# Out:
# Index                                                    128
# State                                                    296
# Road Accidents  during 2018                              296
#  Road Accidents  during 2019                             296
# Road Accidents  during 2020                              296
# Accidents  Per Lakh Population - 2017                    296
# Total Number of Accidents  Per Lakh Population - 2018    296
# Total Number of Accidents  Per Lakh Population - 2019    296
# Total Number of Accidents  Per Lakh Population - 2020    296
# Accidents per 10,000 Vehicles - 2017                     296
# Accidents per 10,000 Vehicles - 2018                     296
# Accidents per 10,000 Vehicles - 2019                     296
# Accidents per 10,000 Km of Roads - 2017                  296
# Accidents per 10,000 Km of Roads - 2018                  296
# Persons Killed 2017                                      296
# ...

# %%
df.nunique()
# Out:
# State                                                    37
# Road Accidents  during 2018                              37
#  Road Accidents  during 2019                             37
# Road Accidents  during 2020                              36
# Accidents  Per Lakh Population - 2017                    35
# Total Number of Accidents  Per Lakh Population - 2018    33
# Total Number of Accidents  Per Lakh Population - 2019    36
# Total Number of Accidents  Per Lakh Population - 2020    36
# Accidents per 10,000 Vehicles - 2017                     36
# Accidents per 10,000 Vehicles - 2018                     34
# Accidents per 10,000 Vehicles - 2019                     34
# Accidents per 10,000 Km of Roads - 2017                  37
# Accidents per 10,000 Km of Roads - 2018                  37
# Persons Killed 2017                                      37
# Persons Killed 2018                                      37
# Persons Killed 2019                                      37
# ...

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\ashik\\Downloads\\archive (1)\\movies.csv")
df

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\ashik\\Downloads\\archive (1)\\movies.csv")
df
# Out:
#        MovieId  ReleaseYear                                         MovieTitle
# 0            1       2003.0                                    Dinosaur Planet
# 1            2       2004.0                         Isle of Man TT 2004 Review
# 2            3       1997.0                                          Character
# 3            4       1994.0                       Paula Abdul's Get Up & Dance
# 4            5       2004.0                           The Rise and Fall of ECW
# ...        ...          ...                                                ...
# 17765    17766       2002.0  Where the Wild Things Are and Other Maurice Se...
# 17766    17767       2004.0                  Fidel Castro: American Experience
# 17767    17768       2000.0                                              Epoch
# 17768    17769       2003.0                                        The Company
# 17769    17770       2003.0                                       Alien Hunter
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17770 entries, 0 to 17769
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MovieId      17770 non-null  int64
#  1   ReleaseYear  17763 non-null  float64
#  2   MovieTitle   17770 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 416.6+ KB

# %%
df.describe()
# Out:
#             MovieId   ReleaseYear
# count  17770.000000  17763.000000
# mean    8885.500000   1990.263694
# std     5129.901477     16.507891
# min        1.000000   1896.000000
# 25%     4443.250000   1985.000000
# 50%     8885.500000   1997.000000
# 75%    13327.750000   2002.000000
# max    17770.000000   2005.000000

# %%
df.max()
# Out:
# MovieId                         17770
# ReleaseYear                    2005.0
# MovieTitle     sex lies and videotape
# dtype: object

# %%
df.min()
# Out:
# MovieId                             1
# ReleaseYear                    1896.0
# MovieTitle     'Allo 'Allo!: Series 1
# dtype: object

# %%
df.head(10)
# Out:
#    MovieId  ReleaseYear                    MovieTitle
# 0        1       2003.0               Dinosaur Planet
# 1        2       2004.0    Isle of Man TT 2004 Review
# 2        3       1997.0                     Character
# 3        4       1994.0  Paula Abdul's Get Up & Dance
# 4        5       2004.0      The Rise and Fall of ECW
# 5        6       1997.0                          Sick
# 6        7       1992.0                         8 Man
# 7        8       2004.0    What the #$*! Do We Know!?
# 8        9       1991.0      Class of Nuke 'Em High 2
# 9       10       2001.0                       Fighter

# %%
df.tail()
# Out:
#        MovieId  ReleaseYear                                         MovieTitle
# 17765    17766       2002.0  Where the Wild Things Are and Other Maurice Se...
# 17766    17767       2004.0                  Fidel Castro: American Experience
# 17767    17768       2000.0                                              Epoch
# 17768    17769       2003.0                                        The Company
# 17769    17770       2003.0                                       Alien Hunter

# %%
df.nunique()
# Out:
# MovieId        17770
# ReleaseYear       94
# MovieTitle     17358
# dtype: int64

# %%
df.shape
# Out:
# (17770, 3)

# %%
df.isnull().sum()
# Out:
# MovieId        0
# ReleaseYear    7
# MovieTitle     0
# dtype: int64

# %%
df.isnull().any()
# Out:
# MovieId        False
# ReleaseYear     True
# MovieTitle     False
# dtype: bool

# %%
df.nunique()
# Out:
# MovieId        17770
# ReleaseYear       94
# MovieTitle     17358
# dtype: int64

# %%
df.memory_usage()
# Out:
# Index             128
# MovieId        142160
# ReleaseYear    142160
# MovieTitle     142160
# dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("C:\\Users\\ashik\\Downloads\\archive (1)\\movies.csv")
df.plot()
plt.show()

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\ashik\\Downloads\\archive (3)\Marijuana_Arrests.csv")
df
# Out:
#                                        TYPE ADULT_JUVENILE  YEAR  \
# 0                                Possession          Adult  2012
# 1                                Possession          Adult  2012
# 2                                Possession          Adult  2012
# 3                                Possession          Adult  2012
# 4      Possession with intent to distribute          Adult  2012
# ...                                     ...            ...   ...
# 13058  Possession with intent to distribute       Juvenile  2021
# 13059  Possession with intent to distribute       Juvenile  2021
# 13060                    Public consumption       Juvenile  2021
# 13061                            Possession       Juvenile  2021
# 13062  Possession with intent to distribute       Juvenile  2021
#
#                      DATETIME                              CCN   AGE  \
# 0      2012/01/01 06:00:00+00                 b';\xc8k~\xa4iJ'  20.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13063 entries, 0 to 13062
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TYPE                13063 non-null  object
#  1   ADULT_JUVENILE      13063 non-null  object
#  2   YEAR                13063 non-null  int64
#  3   DATETIME            13063 non-null  object
#  4   CCN                 12510 non-null  object
#  5   AGE                 12466 non-null  float64
#  6   OFFENSE_DISTRICT    13063 non-null  object
#  7   OFFENSE_PSA         13036 non-null  float64
#  8   OFFENSE_BLOCKX      12461 non-null  float64
#  9   OFFENSE_BLOCKY      12461 non-null  float64
#  10  DEFENDANT_PSA       12328 non-null  object
#  11  DEFENDANT_DISTRICT  12363 non-null  object
#  12  RACE                12510 non-null  object
#  13  ETHNICITY           12510 non-null  object
#  14  SEX                 12510 non-null  object
# ...

# %%
df.describe()
# Out:
#                YEAR           AGE   OFFENSE_PSA  OFFENSE_BLOCKX  \
# count  13063.000000  12466.000000  13036.000000    12461.000000
# mean    2014.644339     29.571394    471.557533   400548.800257
# std        2.704414     10.264332    190.337531     3037.910474
# min     2012.000000     18.000000    101.000000   390300.000000
# 25%     2012.000000     22.000000    305.000000   398100.000000
# 50%     2014.000000     26.000000    506.000000   400400.000000
# 75%     2017.000000     34.000000    607.000000   402200.000000
# max     2021.000000     81.000000    708.000000   407800.000000
#
#        OFFENSE_BLOCKY  ARREST_BLOCKX  ARREST_BLOCKY      OBJECTID
# count    12461.000000   1.209300e+04   12093.000000  13063.000000
# mean    136491.782361   4.005846e+05  136551.352022  19012.000000
# std       3705.734553   7.988281e+03    4533.415194   3771.107618
# min     127900.000000   3.903000e+05  128000.000000  12481.000000
# ...

# %%
df.max()
# Out:
# C:\Users\ashik\AppData\Local\Temp\ipykernel_13320\1151452817.py:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# TYPE                                    Public consumption
# ADULT_JUVENILE                                     Unknown
# YEAR                                                  2021
# DATETIME                            2022/01/01 01:00:00+00
# AGE                                                   81.0
# OFFENSE_DISTRICT                                       Unk
# OFFENSE_PSA                                          708.0
# OFFENSE_BLOCKX                                    407800.0
# OFFENSE_BLOCKY                                    147100.0
# CATEGORY                                         Narcotics
# ...

# %%
df.min()
# Out:
# C:\Users\ashik\AppData\Local\Temp\ipykernel_13320\3962516015.py:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# TYPE                                           Cultivation
# ADULT_JUVENILE                                       Adult
# YEAR                                                  2012
# DATETIME                            2012/01/01 06:00:00+00
# AGE                                                   18.0
# OFFENSE_DISTRICT                                        1D
# OFFENSE_PSA                                          101.0
# OFFENSE_BLOCKX                                    390300.0
# OFFENSE_BLOCKY                                    127900.0
# CATEGORY                                         Narcotics
# ...

# %%
df.head(10)
# Out:
#                                    TYPE ADULT_JUVENILE  YEAR  \
# 0                            Possession          Adult  2012
# 1                            Possession          Adult  2012
# 2                            Possession          Adult  2012
# 3                            Possession          Adult  2012
# 4  Possession with intent to distribute          Adult  2012
# 5                            Possession          Adult  2012
# 6  Possession with intent to distribute          Adult  2012
# 7                            Possession          Adult  2012
# 8  Possession with intent to distribute          Adult  2012
# 9                            Possession          Adult  2012
#
#                  DATETIME                              CCN   AGE  \
# 0  2012/01/01 06:00:00+00                 b';\xc8k~\xa4iJ'  20.0
# 1  2012/01/01 06:00:00+00                 b';\xc8k~\xa4iJ'  23.0
# 2  2012/01/01 06:00:00+00           b't6\xa0\xac\xec`\xa4'  46.0
# ...

# %%
df.tail()
# Out:
#                                        TYPE ADULT_JUVENILE  YEAR  \
# 13058  Possession with intent to distribute       Juvenile  2021
# 13059  Possession with intent to distribute       Juvenile  2021
# 13060                    Public consumption       Juvenile  2021
# 13061                            Possession       Juvenile  2021
# 13062  Possession with intent to distribute       Juvenile  2021
#
#                      DATETIME  CCN  AGE OFFENSE_DISTRICT  OFFENSE_PSA  \
# 13058  2021/12/03 05:00:00+00  NaN  NaN               4D        403.0
# 13059  2021/12/04 05:00:00+00  NaN  NaN               7D        702.0
# 13060  2021/12/11 05:00:00+00  NaN  NaN               4D        403.0
# 13061  2021/12/18 05:00:00+00  NaN  NaN               6D        608.0
# 13062  2021/12/23 05:00:00+00  NaN  NaN               4D        403.0
#
#        OFFENSE_BLOCKX  OFFENSE_BLOCKY  ... ADDRESS ARREST_BLOCKX  \
# 13058             NaN             NaN  ...     NaN           NaN
# ...

# %%
df.shape
# Out:
# (13063, 27)

# %%
df.isnull().sum()
# Out:
# TYPE                    0
# ADULT_JUVENILE          0
# YEAR                    0
# DATETIME                0
# CCN                   553
# AGE                   597
# OFFENSE_DISTRICT        0
# OFFENSE_PSA            27
# OFFENSE_BLOCKX        602
# OFFENSE_BLOCKY        602
# DEFENDANT_PSA         735
# DEFENDANT_DISTRICT    700
# RACE                  553
# ETHNICITY             553
# SEX                   553
# CATEGORY                0
# DESCRIPTION             0
# ADDRESS               582
# ARREST_BLOCKX         970
# ARREST_BLOCKY         970
# GIS_ID                  0
# CREATOR                 0
# CREATED                 0
# EDITOR                  0
# EDITED                  0
# OBJECTID                0
# GLOBALID                0
# dtype: int64

# %%
df.isnull().any()
# Out:
# TYPE                  False
# ADULT_JUVENILE        False
# YEAR                  False
# DATETIME              False
# CCN                    True
# AGE                    True
# OFFENSE_DISTRICT      False
# OFFENSE_PSA            True
# OFFENSE_BLOCKX         True
# OFFENSE_BLOCKY         True
# DEFENDANT_PSA          True
# DEFENDANT_DISTRICT     True
# RACE                   True
# ETHNICITY              True
# SEX                    True
# CATEGORY              False
# DESCRIPTION           False
# ADDRESS                True
# ARREST_BLOCKX          True
# ARREST_BLOCKY          True
# GIS_ID                False
# CREATOR               False
# CREATED               False
# EDITOR                False
# EDITED                False
# OBJECTID              False
# GLOBALID              False
# dtype: bool

# %%
df.nunique()
# Out:
# TYPE                      7
# ADULT_JUVENILE            3
# YEAR                     10
# DATETIME              11285
# CCN                   10372
# AGE                      61
# OFFENSE_DISTRICT          8
# OFFENSE_PSA              57
# OFFENSE_BLOCKX          157
# OFFENSE_BLOCKY          185
# DEFENDANT_PSA            58
# DEFENDANT_DISTRICT        9
# RACE                      8
# ETHNICITY                 6
# SEX                       3
# CATEGORY                  1
# DESCRIPTION              32
# ADDRESS                4866
# ARREST_BLOCKX           159
# ARREST_BLOCKY           184
# GIS_ID                13063
# CREATOR                   1
# CREATED                   1
# EDITOR                    1
# EDITED                    1
# OBJECTID              13063
# GLOBALID              13063
# dtype: int64

# %%
df.plot()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df
# Out:
#                                        TYPE ADULT_JUVENILE  YEAR  \
# 0                                Possession          Adult  2012
# 1                                Possession          Adult  2012
# 2                                Possession          Adult  2012
# 3                                Possession          Adult  2012
# 4      Possession with intent to distribute          Adult  2012
# ...                                     ...            ...   ...
# 13058  Possession with intent to distribute       Juvenile  2021
# 13059  Possession with intent to distribute       Juvenile  2021
# 13060                    Public consumption       Juvenile  2021
# 13061                            Possession       Juvenile  2021
# 13062  Possession with intent to distribute       Juvenile  2021
#
#                      DATETIME                              CCN   AGE  \
# 0      2012/01/01 06:00:00+00                 b';\xc8k~\xa4iJ'  20.0
# ...

# %%
sns.scatterplot(x="YEAR",y="AGE",data=df,hue="OFFENSE_PSA",palette="YlGn")
# Out:
# <Axes: xlabel='YEAR', ylabel='AGE'>

# %%
sns.stripplot(x="YEAR",y="AGE",data=df,hue="OFFENSE_PSA",palette="YlGn",dodge=True)
# Out:
# <Axes: xlabel='YEAR', ylabel='AGE'>

# %%
sns.jointplot(x="YEAR",y="AGE",data=df)

# %%
sns.jointplot(x="YEAR",y="AGE",data=df,kind="kde")

# %%
sns.jointplot(x="YEAR",y="AGE",data=df,kind="kde",cmap="RdBu",shade=True)
# Out:
# C:\Users\ashik\anaconda3\lib\site-packages\seaborn\axisgrid.py:1826: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.pairplot(df.select_dtypes(['number']),hue="OFFENSE_PSA")

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\ashik\AppData\Local\Temp\ipykernel_7388\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >
